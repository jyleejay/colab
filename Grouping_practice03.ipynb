# %% [markdown]
# # Regiment
#
# Check out [Regiment Exercises Video Tutorial](https://youtu.be/MFZ3uakwAEk) to watch a data scientist go through the exercises

# %% [markdown]
# ### Introduction:
#
# Special thanks to: http://chrisalbon.com/ for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create the DataFrame with the following values:

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'],
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %% [markdown]
# ### Step 3. Assign it to a variable called regiment.
# #### Don't forget to name each column

# %%
a = pd.DataFrame(raw_data) # column names are included automatically without define the names using columns = df.keys()

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %% [markdown]
# ### Step 4. What is the mean preTestScore from the regiment Nighthawks?

# %%
regiment[regiment["regiment"] == "Nighthawks"].groupby("regiment").describe()

# %%
regiment[regiment['regiment'] == 'Nighthawks'].groupby('regiment').mean()
# Out:
#             preTestScore  postTestScore
# regiment
# Dragoons           15.50           61.5
# Nighthawks         15.25           59.5
# Scouts              2.50           66.0

# %% [markdown]
# ### Step 5. Present general statistics by company

# %%
des_stats = round(regiment.groupby('company').describe(), 2)
des_stats
# Out:
#         preTestScore                                              \
#                count   mean    std  min   25%   50%    75%   max
# company
# 1st              6.0   6.67   8.52  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.50  14.65  2.0  2.25  13.5  29.25  31.0
#
#         postTestScore
#                 count   mean    std   min    25%   50%   75%   max
# company
# 1st               6.0  57.67  27.49  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.00  14.06  57.0  58.25  62.0  68.0  94.0

# %% [markdown]
# ### Step 6. What is the mean of each company's preTestScore?

# %%
round(regiment.groupby("company").agg({
    "preTestScore": "mean"
}), 2)
# Out:
#          preTestScore
# company
# 1st              6.67
# 2nd             15.50

# %%
round(regiment.groupby('company').preTestScore.mean(), 2)
# Out:
# company
# 1st     6.67
# 2nd    15.50
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 7. Present the mean preTestScores grouped by regiment and company

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 8. Present the mean preTestScores grouped by regiment and company without heirarchical indexing

# %%
# using .agg works fine as well
no_heirarch = regiment.groupby(["regiment", "company"]).agg({
    "preTestScore": "mean"
    })

no_heirarch.reset_index()
# Out:
#      regiment company  preTestScore
# 0    Dragoons     1st           3.5
# 1    Dragoons     2nd          27.5
# 2  Nighthawks     1st          14.0
# 3  Nighthawks     2nd          16.5
# 4      Scouts     1st           2.5
# 5      Scouts     2nd           2.5

# %%
# using .unstack version
regiment.groupby(['regiment', 'company']).preTestScore.mean().unstack()
# Out:
# company      1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %% [markdown]
# ### Step 9. Group the entire dataframe by regiment and company

# %%
regiment.groupby(['regiment', 'company']).mean()
# Out:
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %% [markdown]
# ### Step 10. What is the number of observations in each regiment and company

# %%
regiment.groupby(['company', 'regiment']).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %% [markdown]
# ### Step 11. Iterate over a group and print the name and the whole data from the regiment

# %%
# i don't get the reason why iteration is needed actually...
for group_lable, group in regiment.groupby("regiment"):
  print(group)

# %%
# Group the dataframe by regiment, and for each regiment,
for name, group in regiment.groupby('regiment'):
    # print the name of the regiment
    print(name)
    # print the data of that regiment
    print(group)
# Out:
# Dragoons
#    regiment company    name  preTestScore  postTestScore
# 4  Dragoons     1st   Cooze             3             70
# 5  Dragoons     1st   Jacon             4             25
# 6  Dragoons     2nd  Ryaner            24             94
# 7  Dragoons     2nd    Sone            31             57
# Nighthawks
#      regiment company      name  preTestScore  postTestScore
# 0  Nighthawks     1st    Miller             4             25
# 1  Nighthawks     1st  Jacobson            24             94
# 2  Nighthawks     2nd       Ali            31             57
# 3  Nighthawks     2nd    Milner             2             62
# Scouts
#    regiment company   name  preTestScore  postTestScore
# 8    Scouts     1st  Sloan             2             62
# 9    Scouts     1st  Piger             3             70
# 10   Scouts     2nd  Riani             2             62
# 11   Scouts     2nd    Ali             3             70
